# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Crie uma visualização que mostre o orçamento de todos os filmes do conjunto de dados. Qual o filme com maior orçamento e com menor orçamento?

# %%
filmes_uri = 'https://raw.githubusercontent.com/emanueles/datavis-course/master/assets/files/observable/movies.json'
filmes = pd.read_json(filmes_uri)
filmes.head()
# Out:
#                                           Film  Year      Genre  \
# 0  Harry Potter and the Deathly Hallows Part 2  2011    Fantasy
# 1                         Mission Impossible 4  2011     Action
# 2                                  Toy Story 3  2010  Animation
# 3                                         2012  2009     Action
# 4                          Alice in Wonderland  2010  Adventure
#
#    Worldwide_Gross_M  Budget_M
# 0               1328       125
# 1                689       145
# 2               1063       200
# 3                768       200
# 4               1024       200

# %%
plt.figure(figsize=(15,8))
plt.title('Orçamento de cada filme')
sns.set(style="whitegrid")
sns.barplot(x=filmes.index, y="Budget_M", ci = None, data=filmes)
plt.show()

# %% [markdown]
# Portanto, pelo gráfico vemos que o filme que teve o maior orçamento foi o com o índice 16 e com o menor foi o 13. Podemos descobrir quais são esses filmes usando a biblioteca pandas.

# %%
filmes['Film'][16]
# Out:
# "Pirates of the Caribbean: At World's End"

# %%
filmes['Film'][13]
# Out:
# 'The Twilight Saga: New Moon'

# %% [markdown]
# Crie uma visualização que mostre a bilheteria de todos os filmes do conjunto de dados. Qual o filme com maior bilheteria e com menor bilheteria?

# %%
plt.figure(figsize=(15,8))
plt.title('Bilheteria de cada filme')
sns.set(style="whitegrid")
sns.barplot(x=filmes.index, y="Worldwide_Gross_M", ci = None, data=filmes)
plt.show()

# %% [markdown]
# Portanto, vemos que o filme com a maior bilheteria está no índice 6 e com menor bilheteria está no índice 25. Podemos usar a biblioteca pandas pra descobrir quais são esses filmes.

# %%
filmes['Film'][6]
# Out:
# 'Avatar'

# %%
filmes['Film'][25]
# Out:
# 'Ratatouille'

# %% [markdown]
# Crie uma visualização que mostre a quantidade de filmes por gênero em cada ano. Em que anos foram feitos menos filmes de ação? E em que ano foram feitos menos filmes de animação?

# %%
plt.figure(figsize=(15,8))
plt.title('Filmes por gênero em cada ano')
sns.countplot(x="Year", hue= 'Genre', data=filmes)
plt.show()

# %% [markdown]
# Portanto, os anos em que teve menos filmes de ação foram 2008 e 2010. E, os anos em que teve menos filmes de animação foram 2008 e 2011.

# %% [markdown]
# Crie uma visualização que mostre a média de orçamento de filmes por gênero em cada ano. Em que ano os filmes de ação tiveram maior média de orçamento? E em que ano os filmes de animação tiveram a maior média de orçamento?

# %%
plt.figure(figsize=(15,8))
plt.title('Média de bilheteria por gênero em cada ano')
sns.barplot(x="Year", y = 'Budget_M' , ci = None, hue= 'Genre', data=filmes)
plt.show()

# %% [markdown]
# Portanto, os filmes de ação tiveram um maior orçamento no ano de 2007 enquanto os filmes de animação tiveram um maior orçamento no ano de 2008.
